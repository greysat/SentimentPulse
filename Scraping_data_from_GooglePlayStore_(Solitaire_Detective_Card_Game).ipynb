# %% [markdown]
# <a href="https://colab.research.google.com/github/greysat/SentimentPulse/blob/main/Scraping_data_from_GooglePlayStore_(Solitaire_Detective_Card_Game).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google_play_scraper #scraping reviews
# !pip install -q transformers #sentiment
# !pip install -q plotly-express #data visualization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 48.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 24.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 67.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.7 MB/s eta 0:00:00

# %%
# !pip install pyyaml

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, reviews_all
import plotly.express as px

# %%
solitaire_detective_project = reviews_all( 'br.com.tapps.solitairedetectives', sleep_milliseconds=0, lang='en', country='US')

# %%
solitaire_detective_project
# Out:
# [{'reviewId': 'bb3ac3c9-7e1f-4481-98d8-4bf01bf6d100',
#   'userName': 'Dee Wagner',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIROu7bV_l_XEFTV9YW5NtiaVfzkYkgFVfJ0sQifURt=mo',
#   'content': "This game is ok to play with only 22 cards on table (at times) but you don't know who done it the little story. Because the ads pop-up so you can not find out who!! Maybe the ones who created this game will not have the ads pop-up on you at certain points of the game maybe! Only one star. I had to Uninstalle it because of ads keep locking it up, where you could not even play or go back to first game, so not relaxing!",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.3.18',
#   'at': datetime.datetime(2023, 4, 28, 16, 51, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.3.18'},
#  {'reviewId': '3b72d5d2-45a4-4bc4-95ad-72aab12a77bb',
#   'userName': 'alvenia hill',
# ...

# %%
df = pd.json_normalize(solitaire_detective_project)

# %%
df.head()
# Out:
#                                reviewId              userName  \
# 0  bb3ac3c9-7e1f-4481-98d8-4bf01bf6d100            Dee Wagner
# 1  3b72d5d2-45a4-4bc4-95ad-72aab12a77bb          alvenia hill
# 2  7bc0f58f-412b-4bb9-8000-92b6fcec247d       Patricia Slover
# 3  5690784d-6826-4ec4-8ff8-b0afc428fbab          John Thomson
# 4  c4f9396d-5ac1-4643-b74b-4e9f04177fe1  Taylor Hollingsworth
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  This game is ok to play with only 22 cards on ...      1              0
# 1  I like how you play the daily challenge and co...      5              0
# ...

# %%
df['score'].mean()
# Out:
# 3.903225806451613

# %%
df['reviewCreatedVersion'].value_counts()
# Out:
# 1.1       30
# 1.1.2     21
# 1.2.1     16
# 1.2.2     15
# 1.2       12
# 1.0        9
# 1.0.1      5
# 1.3.6      3
# 1.3.11     2
# 1.3.1      2
# 1.3.18     1
# 1.3.15     1
# 1.3.4      1
# 1.3.3      1
# 1.3        1
# Name: reviewCreatedVersion, dtype: int64

# %%
from transformers import pipeline

sentiment_analysis = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")
# Out:
# (…)a-large-english/resolve/main/config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# (…)glish/resolve/main/tokenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# (…)ta-large-english/resolve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# (…)ta-large-english/resolve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# (…)ish/resolve/main/special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
df['content'] = df['content'].astype('str')

# %%
df['result'] = df['content'].apply(lambda x: sentiment_analysis(x))

# %%
data = df.to_dict(orient='records')

# %%
df['sentiment']=df['result'].apply(lambda x:(x[0]['label']))
df['score']=df['result'].apply(lambda x:(x[0]['score']))

# %%
df['sentiment'].value_counts()
# Out:
# POSITIVE    102
# NEGATIVE     53
# Name: sentiment, dtype: int64

# %%
df.head()
# Out:
#                                reviewId              userName  \
# 0  bb3ac3c9-7e1f-4481-98d8-4bf01bf6d100            Dee Wagner
# 1  3b72d5d2-45a4-4bc4-95ad-72aab12a77bb          alvenia hill
# 2  7bc0f58f-412b-4bb9-8000-92b6fcec247d       Patricia Slover
# 3  5690784d-6826-4ec4-8ff8-b0afc428fbab          John Thomson
# 4  c4f9396d-5ac1-4643-b74b-4e9f04177fe1  Taylor Hollingsworth
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content     score  thumbsUpCount  \
# 0  This game is ok to play with only 22 cards on ...  0.999509              0
# 1  I like how you play the daily challenge and co...  0.993522              0
# ...

# %%
fig = px.histogram(df, x='sentiment', color='sentiment', text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data
# Out:
# [{'reviewId': 'bb3ac3c9-7e1f-4481-98d8-4bf01bf6d100',
#   'userName': 'Dee Wagner',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIROu7bV_l_XEFTV9YW5NtiaVfzkYkgFVfJ0sQifURt=mo',
#   'content': "This game is ok to play with only 22 cards on table (at times) but you don't know who done it the little story. Because the ads pop-up so you can not find out who!! Maybe the ones who created this game will not have the ads pop-up on you at certain points of the game maybe! Only one star. I had to Uninstalle it because of ads keep locking it up, where you could not even play or go back to first game, so not relaxing!",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.3.18',
#   'at': Timestamp('2023-04-28 16:51:07'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.3.18',
#   'result': [{'label': 'NEGATIVE', 'score': 0.9995087385177612}]},
#  {'reviewId': '3b72d5d2-45a4-4bc4-95ad-72aab12a77bb',
#   'userName': 'alvenia hill',
# ...
