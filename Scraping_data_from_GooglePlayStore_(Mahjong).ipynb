# %% [markdown]
# <a href="https://colab.research.google.com/github/greysat/SentimentPulse/blob/main/Scraping_data_from_GooglePlayStore_(Mahjong).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google_play_scraper #scraping reviews
# !pip install -q transformers #sentiment
# !pip install -q plotly-express #data visualization
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 49.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 28.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 57.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 28.6 MB/s eta 0:00:00

# %%
# !pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app, reviews_all
import plotly.express as px

# %%
mahjong_project = reviews_all( 'mahjong.solitaire.mahjongg.titans', sleep_milliseconds=0, lang='en', country='US')

# %%
mahjong_project
# Out:
# [{'reviewId': '2096808e-3ad6-4553-8368-09664a742564',
#   'userName': 'Louise Bhang',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIHj3W9YtHK5HR491MXeoW4UvII5WGexN1uXeOREmVX=mo',
#   'content': 'So far so good!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.26',
#   'at': datetime.datetime(2023, 11, 5, 20, 59, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.26'},
#  {'reviewId': '4edc74e7-ea4e-47c5-88d7-9b11b21105d0',
#   'userName': 'Johnny Saucedo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVE2YcmPyT__rRgFndRJqqM_g7oB2VdM1BizuKUInsu1Q',
#   'content': 'Great!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.26',
#   'at': datetime.datetime(2023, 11, 5, 3, 9, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.26'},
#  {'reviewId': '5d7c6a37-a4e7-4d9e-b100-b36e9a2af5aa',
#   'userName': 'Tyra Ledeen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIusdG_jI9GtFAZmCtSu3jlEssEzUihjlwjkIm7Dp0=mo',
#   'content': 'I. Will. Like. Your. Game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.26',
#   'at': datetime.datetime(2023, 10, 30, 23, 56, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.26'},
#  {'reviewId': 'bc301580-c76d-41be-9a17-51f1d4a660b9',
#   'userName': 'Macy Ferguson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUfXofK3tLCdHKgl-V0kPMg0IYX2gwE8sjf92RSd8s7Z_I',
#   'content': 'Loving it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 8, 29, 16, 39, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '68bcee9d-3d8c-43d6-aee7-1f7a218f6830',
#   'userName': 'Debra Hennig',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXtm2zY21lKAbs_19lnbDJmXu5j6_t-iv93FkUTGUhsWLk',
#   'content': 'Fun & easy',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.25',
#   'at': datetime.datetime(2023, 8, 29, 1, 53, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.25'},
#  {'reviewId': 'c8386ac2-97d0-4045-a16a-03e529db3ba9',
#   'userName': 'Penny Jill Kern “P J” Kurzer',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX3HpT9xG4GJTHJRN2dR4umSW-Cw20YACDswlOJl9XQE_AB',
#   'content': 'great game dont have much time nut its a great game try it sure u will like it',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 30, 5, 37, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': '9cd71d83-7069-4438-8b8f-329cfae92391',
#   'userName': 'Brenda Genrich',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjURa4_84X3sDtjPBt10583t-rf1qhkotuwS86UfObR6X1Q',
#   'content': "I DON'T LIKE YOUR APPS. THEY CHEAT. UNINSTALLING",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 28, 12, 4, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': 'd6d3a8f4-8cf4-42fe-8e88-f06dcbb9e4b3',
#   'userName': 'Juanita Bryant',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ4BhHyLCtiw86OdPerZC_NSvchB6uoqej1E8mtuTTj=mo',
#   'content': "Thanks y'all guys for mahjong game I like it cause it'is so relaxing game to play and fun game so thank yall",
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 13, 21, 44, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': '0c1c0978-bdc6-4633-be2b-afcb97bf24b4',
#   'userName': 'Shay Williams',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL_clklqhnff9e_J_7yLa6BRTBiex1Hh34tw2Cm2Of8=mo',
#   'content': "Greatest game for longer time life's",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 12, 15, 5, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': 'd44b7a15-e2b1-4d80-a87c-2b47c36240d2',
#   'userName': 'Jonne Fritts',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlDcajvRcH9DgJqOt-AWjENxosFid1CkrJCX3zGi15Cg',
#   'content': 'A whole lot of fun!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 10, 23, 33, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': '5ac54241-d3bb-4b76-af8a-ed2e66fe6525',
#   'userName': 'Janizh Arizabal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIFhXUemznNTDoo_vAsEFSCY7dWUC7DSaruYDSJ7o8a=mo',
#   'content': 'Awesome',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 8, 4, 57, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': '0d8a366b-e0d5-4aa7-a070-383e0e5104e8',
#   'userName': 'Paul Niemann',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKVvwAdMaEx1Qhpq2t2v_htG-cOQBX9QAD1sOo5XanP=mo',
#   'content': 'Fun to play. A lot challenge Events and other stuff to do.',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '2.0.21',
#   'at': datetime.datetime(2023, 7, 6, 18, 52, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21'},
#  {'reviewId': '1c9bbd89-1724-48b2-9e8f-d8e5c4a28964',
#   'userName': 'Christi Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLT2sJYbiQS_oyYnDcw6jTKRHHwceh1LLkueyiBX6Rt=mo',
#   'content': 'Great game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 6, 29, 19, 36, 7),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': '87a1843e-14d0-4095-a717-9e753d966cde',
#   'userName': 'Tina',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKUIzmlJKc4P75qnq-TAbJS64rJICWRTPsYnHWTdCqh=mo',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2023, 6, 28, 22, 35, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '7944250c-7bb4-4e64-83ab-109f1aa8664e',
#   'userName': 'Anna Groenewald',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocINpcarmj01ebxAYH4rUJeMsjaYrPD_kICy7a7Iw7A=mo',
#   'content': "It's a fun game and hope the tiles stay big as they are!",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 6, 27, 13, 57, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': '92ed3f6c-ecc8-4240-b015-10a7f1b3f01a',
#   'userName': 'Betty Walden',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUj3pfxGT8BXnijXvWeNkx7pj5dtjiQkTjfbpouUuvqSQ',
#   'content': "So far it's fun.",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 6, 19, 2, 54, 29),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': '640af2ba-e99c-4c77-8a30-829f89299e69',
#   'userName': 'Laronda Mculley',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXzruOSHQaLPqjCZRy5UQv_hKJ5K_yg4C9bEpisFSmUBPg',
#   'content': 'Need more rewards. Make it a bit easy.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 6, 12, 13, 51, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': '1a74bc70-4075-4b8d-8dce-c10a772fdb70',
#   'userName': 'Pebbles Pebbles',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW1crppv-M6w7DZOlW-UI--gjqpvhDKJ6noLvw1Z5zfVgo',
#   'content': 'Its something to do its fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 6, 6, 8, 7, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': 'ae3f7f05-b5bc-48a9-8f7f-e0339b269ffc',
#   'userName': 'Jessie Phillips',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKiJrbyAIgI_vzvCrkh9SU-93vDPa2He2p-g1dQ8a_v=mo',
#   'content': 'Yes its a very good game for sure think u for letting me play jjp.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 6, 3, 2, 13, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': '557eb370-2e7d-4daa-b5c1-2101b85eb434',
#   'userName': 'Elsie Walker',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXEjpHUjl_wKczx-V5k2BCyAWBas_UgBTD5-UwANY81bw',
#   'content': "Can't clear this game at all.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 5, 19, 23, 59, 11),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': 'df079b13-8e61-4fa4-918e-24c2c590f7b1',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Like the bigger tiles',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': datetime.datetime(2023, 5, 18, 3, 46, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19'},
#  {'reviewId': '89bf6402-3f15-4759-973a-e57a17a843c0',
#   'userName': 'Janine Wesley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKyelLnqlfxZL_qNyEEuEyTIxJEFpS0JG1HgTjMhJcO=mo',
#   'content': 'Jam.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2023, 4, 21, 16, 43, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '21e85de7-91de-4bc4-a86e-6028c0be60ab',
#   'userName': 'wiremu layne',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL47IGQOaRd9zA1oiABtcoPeM7xm_DqaBBEcpUogFVDpA=mo',
#   'content': 'This A Awesome Brotha',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2022, 12, 30, 5, 7, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '014143c9-87a8-459c-8427-d4281c9dcc1b',
#   'userName': 'Jdeann Dobyns',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIdHWgVTsNazVW4nQDVqHiHLeKtQ6QS2SvW97H6vm8q=mo',
#   'content': 'yay',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 11, 13, 6, 6, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '0b09d40a-afec-4446-9111-7a1f47628f69',
#   'userName': 'Mac Mcdaniels',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ6mHDL1ls-nmCainJfxpeI8oHjHohsrkaTrMk4hTzm=mo',
#   'content': 'Good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 10, 12, 15, 37, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'c3270a05-98e8-46af-a93c-4441497a420b',
#   'userName': 'Karen Neal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI6d80kleQ4L7l8Sh9oqfIT7cAENRs_aKr6oyphb3Cl=mo',
#   'content': 'AWESOME.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 7, 30, 6, 18, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '2917315f-8c34-4262-b9c1-5b3c2d840483',
#   'userName': 'Amanda',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU4qH0Tc76rG6kB4BJ48IZ9wrDUmEkapeJo5wXdiuWLGvk',
#   'content': 'Fun game...',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 7, 15, 21, 6, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'aba307a4-6554-4f36-961f-db0812d63c1b',
#   'userName': 'Theresa Lafferty',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWgS6GP5YnL4-RdNGEIPG-hnvgvx1IonUpb3UBpRijHjoY7',
#   'content': 'I love this game!! I like it when Popeye helps you with matching the tiles.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 6, 23, 22, 10, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'd00a76de-ed3c-4ef6-a2d8-6415ddb06024',
#   'userName': 'LaRayne Beaverhousen',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXo3suq7seYOhS96CUoS3jRr7-eKYI-HNYGEyxXKgR6iMs',
#   'content': 'Needs more perks to be able to keep playing , as not everyone is able to purchase coins to keep going in the game .',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 6, 10, 8, 26, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '40f20a60-79e3-415b-8c8e-47875a478298',
#   'userName': 'Judy Johnson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJyULNFjsTq_vnZnOTPp9ntHKlY9Dx0LgialhQkt5S1=mo',
#   'content': 'Enjoying it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 6, 3, 18, 53, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '0fd45fe2-1ffd-44b3-9116-7c08a7a1fbc1',
#   'userName': 'Lori Lewis',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJqr6IbHBYmusQtcBs39sPHUp73wpwy5LJQRBNKh4Km=mo',
#   'content': 'Love this game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 6, 1, 16, 7, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '0c9f8ffe-d4a1-475c-9236-e77bfdf8251d',
#   'userName': 'Sylvia Adams',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVL5yL1LjaMiiPnEc_AKxYFqFCBKVDzX5HkQcxkphioN-lB',
#   'content': "Fun game. I used to watch Popeye cartoons way long ago. It's a fun game.",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 25, 5, 47, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'fb9cb284-1ee7-42c8-bc6e-17a84924dd87',
#   'userName': 'Glendaf Giles',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLTCuTv1xxZPir0QxXBCeNZGDkEZKOJOHzNpjb93nRX=mo',
#   'content': 'A Great Game..Relaxing Fun..Love It.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 21, 16, 32, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '72d65840-0059-4499-9bc1-fb1ffbf63ba0',
#   'userName': 'Irene Sim',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV2AGwA94CNIeSAjo8HotWHxcwjtldqVbGaK7EzsdLDQf1X',
#   'content': 'I love Mahjong',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 21, 14, 19, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'becc4a52-a7d2-4d79-ba0e-2d613fcb0f9f',
#   'userName': 'Jose Concepcion',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL_SKv7Xq7Nb8sP7RE02nNIttkOSOxjHMfRNLuAO91a=mo',
#   'content': 'Love the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 20, 16, 36, 39),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '20e35c4e-9154-49e7-8c01-66a0077e3a98',
#   'userName': 'Sulis Clarin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWW11_IUlSkmhpZ5h1BZFlNgKxZyYy0iTIcL5NrIIS6Sv4',
#   'content': 'Awesome',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 19, 5, 1, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '057294a4-77c0-4e33-a5c2-ae9b13943fc7',
#   'userName': 'Eldorina Gaskin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKcnUnRxVVWtXfSFfMG2m-XEY2ZIkgVf56sV5rDY5-D=mo',
#   'content': 'Cool',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 19, 2, 28, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'e435f93f-73de-4bd5-8362-75eb3a29b745',
#   'userName': 'rosalie peterson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIudHPONr44boOQLyJm4FjpZ4y4yI9xNvFvlfkzZlp-=mo',
#   'content': 'love the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 17, 14, 42, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'ea11fdeb-9ab3-494e-94b3-6be856f92313',
#   'userName': 'Zachary Buszta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU_5bVTK-IDTKvpNbgnB30Wyz7In26WO0BscM2Yc_Rr',
#   'content': 'This game is fun to play',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 12, 2, 29, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '1af5e1c4-272e-43eb-b0a8-de098a11731a',
#   'userName': 'Joe Ossinger',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJxadj4q2GLK5HQAjKZr7juRt88TREvx6Pr1RoP3Lpt=mo',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 9, 1, 42, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '1f06fb76-e5a8-4502-bd74-a7d095de2ed2',
#   'userName': 'Cynthia Terrell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIMNy3ECzecOR7tt3qBeSmUcwwlYH9Td6qj3e2wqIut=mo',
#   'content': 'I think this game is great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 6, 17, 58, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '0cdf9d51-08fe-4cad-bcdb-29925593b1f1',
#   'userName': 'Patrick Collins',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocITacuLK4ZqkEXwzFHlo2oXhwGELG9_H-Gi35n5l28j=mo',
#   'content': 'Ok, different and FUN!!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 5, 6, 5, 57, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '5f526c0a-8f63-4ea7-96ec-1065db19c75c',
#   'userName': 'Janet Dear',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIeyyJDz3sAWuSLnBUJWNCYpXzuyScstAcu_fdVGSW1=mo',
#   'content': 'Omg another addictive game love it 👍💖',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 28, 9, 47, 23),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'af5907de-ca71-4dd9-97ee-732c6ccc19b7',
#   'userName': 'Veronica Paton',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXL3CwM5ApfL6h8W53U-XxaofX9vSymuGuDiAWf6cJublsm',
#   'content': 'Fun game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 21, 12, 15, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '2b49c7fb-2385-4ad5-aedc-86c33298e363',
#   'userName': 'Gayle Jordan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKmdkF1Vh2p5cztxzcjjRAFCzYve7ihCW29SONQ3pl_=mo',
#   'content': 'Fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 15, 21, 20, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '9e518086-b1fa-41eb-8483-f1b52762e08b',
#   'userName': 'Darla Bleeke',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJxLcl8-y7qBx0yFKIFx7pvyiXOhqrAuhJSMEMtesqh=mo',
#   'content': 'Fun so far...',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 15, 3, 46, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '1a602680-6e30-47c2-9381-4272c9216c79',
#   'userName': 'ROSA GONZALES',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJIWowS2lHPka62ZiLclDMap5ntLNikCoOfE45cqcN=mo',
#   'content': 'GREAT GAME!!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 15, 0, 24, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '1ffad054-5dff-4132-9b94-c2872b40b048',
#   'userName': 'Stacy Kelly',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXWjEisCBINziOHuOXS-hHE4fuPl2bDkkbuM9oSpVyAABY',
#   'content': 'This game is alot of fun and excitment in it , u will love it',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 14, 8, 14, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': '68a40c96-2fb9-4540-861b-594e9836880a',
#   'userName': 'mary mahoney',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK85W7XMt1BqUQUHehPVrrotithDly9AdZyX_SyFPBU=mo',
#   'content': "Hi I like mahjong it's a good game that's why I rated it 5 stars for love maryanna Mahoney",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 4, 12, 4, 19, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'd85696e8-9fd8-47eb-b8c1-67a5dd859e3b',
#   'userName': 'Carolyn James',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLEljdM6cut9DyW8iqVV_TuvaAMyHksBeMLn_CaQZ_R=mo',
#   'content': 'I like this game.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 11, 20, 16, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'be88bdee-cde5-4bc9-b353-e4f9f2e082f4',
#   'userName': 'Mandy Pugh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIL_ljGUm1U0RY5guxv0N5ZUys4-Zxn5NX_9fWeoUkr=mo',
#   'content': "I just started..but i.love MAHJONG games...so I don't see any problems so far.....",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': datetime.datetime(2022, 4, 6, 7, 4, 57),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13'},
#  {'reviewId': 'd04440c3-df1d-4119-a436-6eaf863c606f',
#   'userName': 'Regina Phillips',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKUHuKxAYTcSpxCgb4yFS8Vs2vJE4HHdMea5Fc6mSpo=mo',
#   'content': 'Lots of fun 😊',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 3, 12, 8, 1, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '7ecbd229-e65f-423b-afe5-cdd04d48a05f',
#   'userName': 'Janice Turner (JanWolf)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWYm87VfWIl2VxYP_Fv6padANhbS-EqUIqMztywahFo0WE',
#   'content': 'This is a very very fun game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 3, 6, 18, 6, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'fc3416e9-296f-462a-844b-26e04af0b695',
#   'userName': 'Souzane Mahmassani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJNmvrMeskrAy6UIukHQjQGN09-KncKg2fXoDdVZXA5=mo',
#   'content': 'Super',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 3, 2, 16, 51, 46),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '73bde7d3-00c1-44d2-8d25-a89ea52a20c4',
#   'userName': 'Crystal Frye',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVAsT5l_v8pKs5NjPml1pp-BIWidThDG6TNd8fKrQWyFXWu',
#   'content': 'Very relaxing and Popyee helps me along the way with explaining how the game works without interfering with the play of the game itself. It is not to easy but on the other hand it is not to hard. I feel that is why I like this game and app.',
#   'score': 5,
#   'thumbsUpCount': 16,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 2, 14, 1, 24, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'f7c27166-aee9-4d23-96bc-b9eba5a9af25',
#   'userName': 'Loretta Adkins',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXSg65kevM3dFriIc0qaX0GZsLDAkYp97Yu9Xa5LCcmGg',
#   'content': 'i love this game it is fun to play.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 2, 8, 22, 2, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '24660f30-f69e-4ae2-9df7-f13d575c2dcb',
#   'userName': 'Conner Mcdaniel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKPLaZ8cja3tYI7MuUMejJqBucG49GjH6c3w3dYPsva=mo',
#   'content': 'Fun game gives my brain a workout',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 2, 1, 5, 48, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'a69e0dcd-7bba-4446-b44a-128db9e7d313',
#   'userName': 'Elizabeth Hughes',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUi0f3_oO9AeBnNDWO25_cK_wZTDrBIxDQcbRpEi_pS6mk',
#   'content': 'Fun & challenging',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 1, 25, 15, 4, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'e7ea9818-d637-4c06-be5c-681e7b761bb5',
#   'userName': 'Lynett Percell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKq0oD6XqVRVVWIclZU59CbQP_lLcAAeAboEdE-7QFz=mo',
#   'content': 'Easy, relaxing and fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 1, 15, 23, 9, 31),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'c16b282d-fa74-4dd0-a02b-66eb862a922c',
#   'userName': 'Daisymae Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIPjPVtj46jONIAwxa9WDcu6X5JvcuRZTiNa2S9yID8=mo',
#   'content': "Great game it's challenging",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 1, 10, 14, 18, 43),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '6a072536-cc37-45c3-881f-702396964662',
#   'userName': 'Sarah Cockburn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIwNF_DijicaLuD-q1UEmpHtASgLW1irhs9QQKtuvlR=mo',
#   'content': 'Good fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 1, 4, 4, 0, 6),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '0565fafc-2a3a-495a-a673-a9126e8d1821',
#   'userName': 'Donna LaBelle',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIjBYGcLgEtbx7cfFDJ3Hu7gFNfiWp_Yjqnd2vSs72F=mo',
#   'content': 'Not bad . A little childish.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2022, 1, 2, 0, 54, 19),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '1e4d6bdd-bf9c-459c-a7d1-d3eb0076ba7c',
#   'userName': 'Colin Bates',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJWqL8mOQ5ohzXzSQq7_1Py-ncu7T4JQrebFysR0pN7=mo',
#   'content': 'Great to play',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 30, 10, 11, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '7690f09a-2c4d-4471-b9e3-6c8ba7f98ec8',
#   'userName': 'Julie Carter',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXwwDS8sV4FgqnGSkVaunR2YOqkKgW5qmMbU85Bsru0Ew',
#   'content': 'Ii like it. Its not to easy and sometimes its pretty hard but not impossible',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 30, 9, 43, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'ce64e9c2-e347-458a-809c-cba7239650c3',
#   'userName': 'Audrey Brown',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI-LcnKillY_tioEZbgx7lFEHFHne1cygpANmkxYYgW=mo',
#   'content': 'Awesome Very. GRAPICS',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 29, 15, 52, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '29cca975-5dd6-4542-a25d-b7e71333357b',
#   'userName': 'steve brister',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI_wIXhWk7KJojEGza8IcNATBk-GxdKMBqhxO1Mc5Z1=mo',
#   'content': "It's more for the kids.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 28, 8, 0, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '8cec8a53-d0b2-422b-a5c4-2534520f383b',
#   'userName': 'Victoria Foster',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL6G-rUbmtU5aHyQfsQc3xlCUrxRM_Hp1QVQ-8puq9i=mo',
#   'content': 'Silly and fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 27, 13, 56, 16),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'e5e97d40-d212-45c6-ba3d-788a0e5c8f83',
#   'userName': 'Lisa Malone',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLlm11l6WXrcouoWKACnmD5mV861Z6_QaZEqA3yZyXP=mo',
#   'content': 'Enjoy getting to the next level',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 27, 4, 33, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'f6f242c9-aa1a-41aa-ac14-f16d54926b45',
#   'userName': 'Margo Kelley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKFlC7cPSN97lz21uh0M2BWZq6D6B9Mxu9rVOU-ZAu4zA=mo',
#   'content': 'Helps me too relax',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 26, 22, 20, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '37c1b1d1-79a5-4b16-b69f-ae8bd650acce',
#   'userName': 'Alana Brown',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIPcO3uVFqUrNTiZdBZEOhZ9ZP7s5uRWgI7fJLDK-gz=mo',
#   'content': 'game would not let me play',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 12, 16, 0, 12, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'aec7790a-4830-4c5c-b240-a4e92792498c',
#   'userName': 'Marianne Hinrichs',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKCImmHf0xKEaFQrGmiiWVirtuH6hEYj5UQrhPomzIE=mo',
#   'content': 'this is fun an you have to think to make yourovr',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 14, 10, 20, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '3a486da7-cff0-4608-b3e3-c7ae229764cc',
#   'userName': 'Melodee Hacker',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXRXRGOQ59446fkK88amdUSonwBZ2P33zxwPmwOdA8fEh4',
#   'content': 'Fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 13, 19, 46, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '958f29a9-3730-4da2-bcef-3073d33e25bf',
#   'userName': 'Tammy Simpson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIe78JxS-iHX_-_qkZVFWmtd3-LcVo87y-d-nQ3EcCh=mo',
#   'content': 'Good game',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 12, 9, 23, 20, 38),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '740b8f4a-a966-49d3-8013-caee19a39a9c',
#   'userName': 'Ronald Bianco',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKZ3bRZuvoY1XNO7jpYNzRGURYy3mgl1_y_XJCfnF6k=mo',
#   'content': "A fun game to play. I wish that I could slide to connect, but i can't. BE SAFE, GOD BLESS ...",
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 8, 19, 4, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'd08b3c8f-14e8-461f-ab2b-4347696f86e8',
#   'userName': 'DeLinda Wagner',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJuTFIjfRJHtwS14PrBvcNOWezhb_6zZ8MhcQTXdcVP=mo',
#   'content': 'Fun and can get challenging at times',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 4, 5, 24, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '285b4e2c-fc96-4610-8255-8e2119c1a441',
#   'userName': 'Kristine Barfknecht',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX9Lvnn6wJ_dkJisH5M8jy9ZRV2ypkgUJYSJXf_2Z9sqY0',
#   'content': 'Alot of fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 1, 22, 6, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'fa427c76-57cc-4e46-b952-ca55021d1441',
#   'userName': 'Britt Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJgJDWwxXk-pxJs7f1hIsAShr9mt6TBqbNla0YLa60=mo',
#   'content': 'Fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 12, 1, 5, 37, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'b90ae393-cd47-4a03-9df8-0fff6c90be4d',
#   'userName': 'Angela Comstock',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVBw4qg2iuvQuqCkCrKfNnyDAHaOsuzYbVRv1gNylD4Iq4I',
#   'content': 'Love this game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 30, 13, 43, 2),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '6531c4d5-a297-42a7-b743-3c5f2331ac74',
#   'userName': 'Angela Rotundo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKTD4Mmp8h3eNP88JwlKJDkBwvnfTKAfJfE4xa8j0-s=mo',
#   'content': 'Like the fact no vendors to watch during levels',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 29, 21, 55, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'd9f3a434-7059-471f-a2cb-49f5e3c23aca',
#   'userName': 'Lolita Tesoro',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKXzbi-RAF4LrGhBInuswNs5nlW6Cjq_v1-Fv12ogA1=mo',
#   'content': 'I like how the pieces start',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 28, 8, 0, 51),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '2acdf2bf-ab63-4035-a4d9-d448d55e2195',
#   'userName': 'Nathan Esparza',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLRxe5vzqF-wp-w0ABPRbo1HfFKSdDLX56u_DUwuFUS=mo',
#   'content': 'Not a bad game at all',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 26, 20, 38, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '02fb1cbe-29c4-43f5-bf52-777ff578d648',
#   'userName': 'Alan Thomas',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU3IZiFyakFy4q4q3A479z9-Dn8Lp-MonM2jLkpo4v-JQ',
#   'content': 'Good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 26, 15, 11, 41),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'b719f774-95ed-47f7-b431-5ff39bb481db',
#   'userName': 'Troy Raber',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJGzHCKsXRLKYRyrD37NDs25B0j7YIZXf01LmMAq41f=mo',
#   'content': 'Boring',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 24, 23, 59, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'c90445d1-5214-479d-8bdc-42efaf31047d',
#   'userName': 'Carol Ryckert',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKdC-LcRb0F7pqN9SkDRq-ngwKC-eXScmnUS2jjU5X4=mo',
#   'content': 'just keep you occupied for a while.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 23, 9, 53, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'df30b4fa-3018-4d1e-b4fb-88e6f00951ed',
#   'userName': 'Msrgaret Flores',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKWTumrhkAtZqGSAwmlaZcvKh313S9SHzzSw4HYUzod=mo',
#   'content': 'Fun fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 21, 13, 32, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '65d1b1ac-9f95-4fc3-af2c-6853c70b099d',
#   'userName': 'kim graham',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLuOTL6ACJyA1o8GgUH-FejDKGaHcU4W-yAxZrhV5ql=mo',
#   'content': 'Good game so far, loads fast no glitches',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 20, 17, 58, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '1381b794-6a25-49f2-8bbe-b20ce391b480',
#   'userName': 'kehli armstrong',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIsWx0kbmhT0C1ZyXXv-5PGgAbryP2S8U0FVDezLXys=mo',
#   'content': 'Fun and entertaining',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 17, 23, 26, 56),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '675789e1-5ffc-4cd6-b772-7d137f8e4fad',
#   'userName': 'Catherine Martin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJsySZU_u-6zN5DYJ2GhbYiGLCrdrEen4IpXpSMM5ar=mo',
#   'content': 'A fun game to play!!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 17, 21, 12, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '6b66c573-fdf8-4842-a57c-c98022e139ae',
#   'userName': 'Lady Van Niekerk',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK2n6Gn-OHTQQm3d1DmXGxyRvqMFJTCzeHk6TqMnBqr=mo',
#   'content': "Can't get past level 193 I just luv this game pse help me please I would live to go to 194 to carry on pse the so much lady from south africa",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 16, 10, 30, 24),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '25ad56f7-2033-4f21-9d93-7c2ac985fb54',
#   'userName': 'April Stamant',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVy_nf_xxTf6uaS5zhvOHGZpjAjydInF6D205B4nfvtZB8',
#   'content': 'So far so good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 13, 21, 14, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '3d5a74dd-59e7-4db9-bff2-d987364b4319',
#   'userName': 'Dorothy Linen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIehQpyEB3vMrb21vKCTlaX98_If3ULY3LXYbngLDHU=mo',
#   'content': 'The game is relaxing fun and easy. I really like the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 13, 9, 18, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '11f56f57-e820-48ca-9303-ccde49c3bbf4',
#   'userName': 'Maryanne Tinder Osborne',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWQ5iBTVXEVcjdgmrImkUt_IybqvMdPOJHrdTRyltzIuQc',
#   'content': "It's OK and uses your brain for sure",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 12, 23, 24, 14),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '58033e01-b004-4ced-8003-ef88a08a2112',
#   'userName': 'rebecca chick',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL_JVQrMDiWTHZ28-nLFLX-YV6LlPCAaPuudtWbfWmssA=mo',
#   'content': 'Very good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 11, 10, 20, 49, 37),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '0c2b419d-2295-42d1-b803-eddca42ba869',
#   'userName': 'Aurea Cubero',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLueqmBOz2msxmlMP2bb72_mzNb1h6QnK5X51Tab4_W=mo',
#   'content': 'Great game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 10, 7, 24, 34),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '2f33eeac-fb22-47e9-8ce8-e67f88fa8e8b',
#   'userName': 'Shana Rahman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWgypEhfrK8AoRtXi0Ez30fL9u02K9rINLwijZT13yTg04L',
#   'content': 'Love this game... passes time',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 8, 15, 8, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'cdb40e91-d90f-44bd-b42c-a3d4169d26c9',
#   'userName': 'Anita Ann Ogden',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVmT_0sUBT2mlwdAcJ4r40pMa29hmCO1mmHn30q24XTfpY',
#   'content': 'Fun and relaxing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 6, 21, 3, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '552a0e21-ce98-4a91-855c-630e650844c7',
#   'userName': 'Darlene Sensky',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXtk5RagGUfdt5YEGbtieF7tN6afjvBV7F5yD94FjcZkL4',
#   'content': 'Great Mahjong game! I love Popeye. He was my favorite when I was growing up!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2021, 11, 6, 16, 32, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'b101fe68-bb61-4934-8a40-ac66b0545a53',
#   'userName': 'Kizzy Dutton',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIlMCe0QbOkkjPREXFqcw7vwCMxSkEyegCu-S6IVxi-=mo',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 6, 6, 35, 13),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '3b0d0106-dfd7-402c-8897-3bb00d5cbd5d',
#   'userName': 'Linda Wilson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJIdrdMi9guaQRk5T7oUTHPUmkNv6RstmK0i0arTF3X=mo',
#   'content': "Very easy way to learn Mahjong. Good ol' Popeye providing the encouragement.",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 6, 2, 1, 9),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '62b353f0-8b3c-47b1-8224-8b9553e7f370',
#   'userName': 'Hal Woodmansee',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKOft_wPLpbROFiUem2EDlR0uNwILHU9QBNRe0nqDdI=mo',
#   'content': "He don't realize it that it's hard to put down",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 6, 0, 6, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '4b9b6bc4-72b1-40d1-840e-3edef1c0b003',
#   'userName': 'teresa gerrard',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIwj7hopMZ6ybOlOdOyXVjWmkziM4siZlPII960Isi4=mo',
#   'content': 'A very enjoyable game to enjoy.Well made guys & girls. More of the same type of games pls soon!!!',
#   'score': 5,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 4, 16, 59, 26),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '68052bcb-1f0a-44a2-8d28-757a3a2f478b',
#   'userName': 'Mogzy67',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL5nGOXXGUYCzXyDW53rTrE8DDXuAiQ0qSh29OvQWvg=mo',
#   'content': 'Fun and addictive',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 11, 1, 13, 51, 25),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '23ea82ec-c63d-4bb8-ab1f-0103f1b985cd',
#   'userName': 'Jennifer Green (Jennilynn)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVUACTwiTjuZ8j0hhXEbR4-e2msQEsb7gn32KG682DU4Ng',
#   'content': "I'm a big fan of popeye . I'm loving it",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 30, 21, 22, 33),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '99d89e6b-4638-4a95-9679-580b3833384e',
#   'userName': 'Theresa Holley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKkDXEWfaWxaWC6rn8gSrSzFG811hUhCi1eplubCfZe=mo',
#   'content': 'I love popeye in anything he does.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 30, 6, 57, 3),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '21130533-bce3-4622-a04e-bf0a7904e9c1',
#   'userName': 'sandra tilbury',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVxhbdoP_AwF1UxXMvkixpZC6p9TGkASnv9oH1HktVtvA',
#   'content': 'very good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 30, 4, 19, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '740d58bb-6ffb-41a8-a131-871af54a8c13',
#   'userName': 'Anthony Rivers',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXa1xnp9_d4LiUWx59_eQ4IwFOX_HWk1Buixa2_2rNJUA8',
#   'content': 'Nice',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 29, 16, 59),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'b1e29dba-2026-4646-b72f-fadd66837cb8',
#   'userName': 'Jerri Anne Mostella',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJFAauzoFcR1wRH6P1mnZ0eBor_UN5N2euIST72YN4G=mo',
#   'content': 'Very fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 29, 0, 51, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'd5c3c18c-0362-4757-8d31-14a3eb30f8db',
#   'userName': 'Carmon Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKtg1ZL06EvNm8GknWyOyWX0GMG1l6pClbqpClmXPER=mo',
#   'content': 'Great grapics so fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 28, 3, 29, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': 'b64fc203-3275-4e34-91e9-1497e1fb1657',
#   'userName': 'Mary Shelton',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK5cfUmwO9EvDDzbit-ce0WgHQEzozURNbKtrJgvug5=mo',
#   'content': 'I love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': datetime.datetime(2021, 10, 28, 3, 10, 5),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7'},
#  {'reviewId': '4b1d3e2f-c8b0-4886-a4cc-fdc20884f8ba',
#   'userName': 'Kaelynn Coulthard',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLkUsm86jDUniLLwVKf0xY1l02ICjseulSj1IvrAyX8AQ=mo',
#   'content': 'Fun',
# ...
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': '152d915f-0865-409d-953c-009967831f06',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Stops at Level 72',
#   'score': 3,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 10, 26, 3, 36, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': '711e0df9-e721-4a27-84a1-59c5f614ab02',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Beautiful game. Love it!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 10, 21, 17, 51, 15),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': 'b125b507-a4d3-48a5-b8d1-e65b9bcdbb49',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Very relaxing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 10, 12, 17, 0, 47),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': '9f228715-283b-466a-8529-4cb70e80f981',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Loved',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 10, 7, 9, 4, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': 'd40cb1ef-62fd-4ff8-88d2-056f50e61acf',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Nice game.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 10, 2, 0, 11, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': 'df6df421-1680-48b4-a8ba-5fa935555819',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'It stops at level 86.',
#   'score': 3,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 10, 1, 4, 52, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': '1f0930ef-e6e9-4108-8f2d-d45999115024',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'I like all solitare ,another one play.FUN!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 9, 25, 18, 24, 40),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': '0aca9459-5e86-440e-80c3-db66014618e7',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'I love the fun sounds and colors. The game is not annoying and easy to play. : ) ...I like it!!!!!',
#   'score': 5,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '1.1',
#   'at': datetime.datetime(2016, 9, 25, 3, 6, 10),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1'},
#  {'reviewId': '7c0d2a7f-e840-4fea-9328-348aa4467fbc',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'loved it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 23, 6, 40, 36),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'bc378749-4835-4345-bc5d-11013c2eb27c',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'One of my favorites',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 19, 0, 18, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'ca4ceb49-2572-4b63-8dbb-a29a0f982900',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Fun times.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 17, 22, 4, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'bec911e5-7f52-4fbb-80b1-aa5384f15ca5',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Fun.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 17, 18, 51, 22),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'bd8822ec-a4ff-4487-a849-d1e7d10f1a70',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 16, 22, 31, 1),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'b881e7b4-cbc0-400a-9447-31f1bb864520',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Ok',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 15, 9, 49, 58),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '3912bdc9-db00-4888-929b-860fc1e9b6f2',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "Great game I'm finding it very addictive",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 6, 20, 24, 44),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '054d5e04-f496-4f93-8282-58dfb33b68b2',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Nice game keeps yah busy.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 6, 3, 51, 18),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '59ce21ef-168e-4314-994a-cb44ce827814',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "But I'm sure it'll get more appealing as I play the game further  😊",
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 9, 6, 2, 1, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '573afe34-e514-42d7-adee-09a7bc5f7b13',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Good game like the underwater scenes and tiles',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 31, 13, 20, 32),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'f1ceced7-6371-48b8-a2ed-4ca01695994d',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "It's got nice music and cute tiles",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 29, 20, 26, 49),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'e3784b8b-aa63-4f05-818f-26854d304201',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "My Little ones like it. Good for short attention spans of kids, before they get bored game's over.",
#   'score': 4,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 27, 2, 22, 54),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '4a368a8f-345e-4766-ab78-0231eba93672',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Love it and it was a blast',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 25, 18, 30, 4),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'fb5f20b3-b722-4208-9e0c-ad097d1db03a',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Thks',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 18, 7, 6, 30),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'e79b3cf1-c94e-4ebf-aaaf-fb1302988a8b',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "It's fun",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 18, 1, 37, 55),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '29853424-14e9-4a21-b9b0-2bfdca5a716b',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Lot of fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 16, 1, 27, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'e691b4e2-65d3-49b9-82cb-2df17605d425',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Trying another game so addictive !!',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 14, 21, 56, 17),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '4b8e4f6e-9b09-44b8-a7ae-6b3de2ae0fd9',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Moving all the tiles until the board is completed with all tiles matching',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 13, 23, 32, 45),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'd05be434-84a9-40e4-b148-6a81a9b34f45',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Great game.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 11, 0, 19, 8),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '7c967967-49ed-4284-ac7a-6a98aae64f6c',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Excellent.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2016, 8, 10, 13, 59, 12),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': 'bc7c1dfc-92f2-4797-90a7-9134c119e83d',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Its good game thanks.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 10, 7, 44, 48),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': 'e9770837-a3d0-406d-9173-26ac8fd0fba1',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Gotgold',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 9, 13, 48, 35),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '2611b8d2-8dd7-4cf4-b816-e36b0da11892',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Its a good game to play',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 6, 1, 43, 53),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '4275ee7f-98f0-4548-bb21-10c8c5d7eb62',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Relaxing',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 3, 23, 27, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '194679ca-5ef2-480e-b64b-84fb2b99d6ac',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Like the tiles',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': datetime.datetime(2016, 8, 3, 7, 34, 42),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None},
#  {'reviewId': '110b9f80-3135-4e90-9a1c-b10102d19625',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Loved',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 8, 1, 7, 44, 52),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'},
#  {'reviewId': '4df0c0ad-ac36-4aaf-8c06-e84806abd46f',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Good job try to improve your self',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': datetime.datetime(2016, 7, 31, 11, 29, 20),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0'}]

# %%
df = pd.json_normalize(mahjong_project)

# %%
df.head()
# Out:
#                                reviewId        userName  \
# 0  2096808e-3ad6-4553-8368-09664a742564    Louise Bhang
# 1  4edc74e7-ea4e-47c5-88d7-9b11b21105d0  Johnny Saucedo
# 2  5d7c6a37-a4e7-4d9e-b100-b36e9a2af5aa     Tyra Ledeen
# 3  bc301580-c76d-41be-9a17-51f1d4a660b9   Macy Ferguson
# 4  68bcee9d-3d8c-43d6-aee7-1f7a218f6830    Debra Hennig
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                      content  score  thumbsUpCount reviewCreatedVersion  \
# 0            So far so good!      5              0               2.0.26
# 1                     Great!      5              0               2.0.26
# 2  I. Will. Like. Your. Game      5              0               2.0.26
# 3                  Loving it      5              0                 None
# 4                 Fun & easy      5              0               2.0.25
#
#                    at replyContent repliedAt appVersion
# 0 2023-11-05 20:59:52         None      None     2.0.26
# 1 2023-11-05 03:09:30         None      None     2.0.26
# 2 2023-10-30 23:56:09         None      None     2.0.26
# 3 2023-08-29 16:39:59         None      None       None
# 4 2023-08-29 01:53:56         None      None     2.0.25

# %%
df['score'].mean()
# Out:
# 4.523504273504273

# %%
df['reviewCreatedVersion'].value_counts()
# Out:
# 2.0.7     351
# 2.0.13     26
# 1.0        25
# 1.1        23
# 2.0.19      8
# 2.0.21      7
# 2.0.26      3
# 2.0.25      1
# Name: reviewCreatedVersion, dtype: int64

# %%
from transformers import pipeline

sentiment_analysis = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")
# Out:
# (…)a-large-english/resolve/main/config.json:   0%|          | 0.00/687 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# (…)glish/resolve/main/tokenizer_config.json:   0%|          | 0.00/256 [00:00<?, ?B/s]
# (…)ta-large-english/resolve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# (…)ta-large-english/resolve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# (…)ish/resolve/main/special_tokens_map.json:   0%|          | 0.00/150 [00:00<?, ?B/s]

# %%
df['content'] = df['content'].astype('str')

# %%
df['result'] = df['content'].apply(lambda x: sentiment_analysis(x))

# %%
data = df.to_dict(orient='records')

# %%
df['sentiment']=df['result'].apply(lambda x:(x[0]['label']))
df['score']=df['result'].apply(lambda x:(x[0]['score']))

# %%
df['sentiment'].value_counts()
# Out:
# POSITIVE    419
# NEGATIVE     49
# Name: sentiment, dtype: int64

# %%
df.head()
# Out:
#                                reviewId        userName  \
# 0  2096808e-3ad6-4553-8368-09664a742564    Louise Bhang
# 1  4edc74e7-ea4e-47c5-88d7-9b11b21105d0  Johnny Saucedo
# 2  5d7c6a37-a4e7-4d9e-b100-b36e9a2af5aa     Tyra Ledeen
# 3  bc301580-c76d-41be-9a17-51f1d4a660b9   Macy Ferguson
# 4  68bcee9d-3d8c-43d6-aee7-1f7a218f6830    Debra Hennig
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                      content     score  thumbsUpCount reviewCreatedVersion  \
# 0            So far so good!  0.998401              0               2.0.26
# 1                     Great!  0.998596              0               2.0.26
# 2  I. Will. Like. Your. Game  0.997581              0               2.0.26
# 3                  Loving it  0.998852              0                 None
# 4                 Fun & easy  0.998844              0               2.0.25
#
#                    at replyContent repliedAt appVersion  \
# 0 2023-11-05 20:59:52         None      None     2.0.26
# 1 2023-11-05 03:09:30         None      None     2.0.26
# 2 2023-10-30 23:56:09         None      None     2.0.26
# 3 2023-08-29 16:39:59         None      None       None
# 4 2023-08-29 01:53:56         None      None     2.0.25
#
#                                               result sentiment
# 0  [{'label': 'POSITIVE', 'score': 0.998401224613...  POSITIVE
# 1  [{'label': 'POSITIVE', 'score': 0.998596489429...  POSITIVE
# 2  [{'label': 'POSITIVE', 'score': 0.997581124305...  POSITIVE
# 3  [{'label': 'POSITIVE', 'score': 0.998851776123...  POSITIVE
# 4  [{'label': 'POSITIVE', 'score': 0.998844027519...  POSITIVE

# %%
fig = px.histogram(df, x='sentiment', color='sentiment', text_auto=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="363dc372-4b9f-43cf-8738-de47f6fac57b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("363dc372-4b9f-43cf-8738-de47f6fac57b")) {                    Plotly.newPlot(                        "363dc372-4b9f-43cf-8738-de47f6fac57b",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"sentiment=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"POSITIVE","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"POSITIVE","offsetgroup":"POSITIVE","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE","POSITIVE" ...

# %%
data
# Out:
# [{'reviewId': '2096808e-3ad6-4553-8368-09664a742564',
#   'userName': 'Louise Bhang',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIHj3W9YtHK5HR491MXeoW4UvII5WGexN1uXeOREmVX=mo',
#   'content': 'So far so good!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.26',
#   'at': Timestamp('2023-11-05 20:59:52'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.26',
#   'result': [{'label': 'POSITIVE', 'score': 0.9984012246131897}]},
#  {'reviewId': '4edc74e7-ea4e-47c5-88d7-9b11b21105d0',
#   'userName': 'Johnny Saucedo',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVE2YcmPyT__rRgFndRJqqM_g7oB2VdM1BizuKUInsu1Q',
#   'content': 'Great!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.26',
#   'at': Timestamp('2023-11-05 03:09:30'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.26',
#   'result': [{'label': 'POSITIVE', 'score': 0.9985964894294739}]},
#  {'reviewId': '5d7c6a37-a4e7-4d9e-b100-b36e9a2af5aa',
#   'userName': 'Tyra Ledeen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIusdG_jI9GtFAZmCtSu3jlEssEzUihjlwjkIm7Dp0=mo',
#   'content': 'I. Will. Like. Your. Game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.26',
#   'at': Timestamp('2023-10-30 23:56:09'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.26',
#   'result': [{'label': 'POSITIVE', 'score': 0.9975811243057251}]},
#  {'reviewId': 'bc301580-c76d-41be-9a17-51f1d4a660b9',
#   'userName': 'Macy Ferguson',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUfXofK3tLCdHKgl-V0kPMg0IYX2gwE8sjf92RSd8s7Z_I',
#   'content': 'Loving it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2023-08-29 16:39:59'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9988517761230469}]},
#  {'reviewId': '68bcee9d-3d8c-43d6-aee7-1f7a218f6830',
#   'userName': 'Debra Hennig',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXtm2zY21lKAbs_19lnbDJmXu5j6_t-iv93FkUTGUhsWLk',
#   'content': 'Fun & easy',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.25',
#   'at': Timestamp('2023-08-29 01:53:56'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.25',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988440275192261}]},
#  {'reviewId': 'c8386ac2-97d0-4045-a16a-03e529db3ba9',
#   'userName': 'Penny Jill Kern “P J” Kurzer',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX3HpT9xG4GJTHJRN2dR4umSW-Cw20YACDswlOJl9XQE_AB',
#   'content': 'great game dont have much time nut its a great game try it sure u will like it',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-30 05:37:42'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988157749176025}]},
#  {'reviewId': '9cd71d83-7069-4438-8b8f-329cfae92391',
#   'userName': 'Brenda Genrich',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjURa4_84X3sDtjPBt10583t-rf1qhkotuwS86UfObR6X1Q',
#   'content': "I DON'T LIKE YOUR APPS. THEY CHEAT. UNINSTALLING",
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-28 12:04:15'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'NEGATIVE', 'score': 0.999496340751648}]},
#  {'reviewId': 'd6d3a8f4-8cf4-42fe-8e88-f06dcbb9e4b3',
#   'userName': 'Juanita Bryant',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ4BhHyLCtiw86OdPerZC_NSvchB6uoqej1E8mtuTTj=mo',
#   'content': "Thanks y'all guys for mahjong game I like it cause it'is so relaxing game to play and fun game so thank yall",
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-13 21:44:43'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'POSITIVE', 'score': 0.998923122882843}]},
#  {'reviewId': '0c1c0978-bdc6-4633-be2b-afcb97bf24b4',
#   'userName': 'Shay Williams',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL_clklqhnff9e_J_7yLa6BRTBiex1Hh34tw2Cm2Of8=mo',
#   'content': "Greatest game for longer time life's",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-12 15:05:05'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987046718597412}]},
#  {'reviewId': 'd44b7a15-e2b1-4d80-a87c-2b47c36240d2',
#   'userName': 'Jonne Fritts',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUlDcajvRcH9DgJqOt-AWjENxosFid1CkrJCX3zGi15Cg',
#   'content': 'A whole lot of fun!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-10 23:33:41'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'POSITIVE', 'score': 0.998826801776886}]},
#  {'reviewId': '5ac54241-d3bb-4b76-af8a-ed2e66fe6525',
#   'userName': 'Janizh Arizabal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIFhXUemznNTDoo_vAsEFSCY7dWUC7DSaruYDSJ7o8a=mo',
#   'content': 'Awesome',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-08 04:57:46'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986000657081604}]},
#  {'reviewId': '0d8a366b-e0d5-4aa7-a070-383e0e5104e8',
#   'userName': 'Paul Niemann',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKVvwAdMaEx1Qhpq2t2v_htG-cOQBX9QAD1sOo5XanP=mo',
#   'content': 'Fun to play. A lot challenge Events and other stuff to do.',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '2.0.21',
#   'at': Timestamp('2023-07-06 18:52:53'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.21',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988377690315247}]},
#  {'reviewId': '1c9bbd89-1724-48b2-9e8f-d8e5c4a28964',
#   'userName': 'Christi Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLT2sJYbiQS_oyYnDcw6jTKRHHwceh1LLkueyiBX6Rt=mo',
#   'content': 'Great game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-06-29 19:36:07'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.998761773109436}]},
#  {'reviewId': '87a1843e-14d0-4095-a717-9e753d966cde',
#   'userName': 'Tina',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKUIzmlJKc4P75qnq-TAbJS64rJICWRTPsYnHWTdCqh=mo',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2023-06-28 22:35:26'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9988111257553101}]},
#  {'reviewId': '7944250c-7bb4-4e64-83ab-109f1aa8664e',
#   'userName': 'Anna Groenewald',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocINpcarmj01ebxAYH4rUJeMsjaYrPD_kICy7a7Iw7A=mo',
#   'content': "It's a fun game and hope the tiles stay big as they are!",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-06-27 13:57:30'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988431930541992}]},
#  {'reviewId': '92ed3f6c-ecc8-4240-b015-10a7f1b3f01a',
#   'userName': 'Betty Walden',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUj3pfxGT8BXnijXvWeNkx7pj5dtjiQkTjfbpouUuvqSQ',
#   'content': "So far it's fun.",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-06-19 02:54:29'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988007545471191}]},
#  {'reviewId': '640af2ba-e99c-4c77-8a30-829f89299e69',
#   'userName': 'Laronda Mculley',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXzruOSHQaLPqjCZRy5UQv_hKJ5K_yg4C9bEpisFSmUBPg',
#   'content': 'Need more rewards. Make it a bit easy.',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-06-12 13:51:54'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.9813833832740784}]},
#  {'reviewId': '1a74bc70-4075-4b8d-8dce-c10a772fdb70',
#   'userName': 'Pebbles Pebbles',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjW1crppv-M6w7DZOlW-UI--gjqpvhDKJ6noLvw1Z5zfVgo',
#   'content': 'Its something to do its fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-06-06 08:07:30'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987354874610901}]},
#  {'reviewId': 'ae3f7f05-b5bc-48a9-8f7f-e0339b269ffc',
#   'userName': 'Jessie Phillips',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKiJrbyAIgI_vzvCrkh9SU-93vDPa2He2p-g1dQ8a_v=mo',
#   'content': 'Yes its a very good game for sure think u for letting me play jjp.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-06-03 02:13:39'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987887740135193}]},
#  {'reviewId': '557eb370-2e7d-4daa-b5c1-2101b85eb434',
#   'userName': 'Elsie Walker',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXEjpHUjl_wKczx-V5k2BCyAWBas_UgBTD5-UwANY81bw',
#   'content': "Can't clear this game at all.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-05-19 23:59:11'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'NEGATIVE', 'score': 0.9994951486587524}]},
#  {'reviewId': 'df079b13-8e61-4fa4-918e-24c2c590f7b1',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Like the bigger tiles',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.19',
#   'at': Timestamp('2023-05-18 03:46:56'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.19',
#   'result': [{'label': 'POSITIVE', 'score': 0.997490644454956}]},
#  {'reviewId': '89bf6402-3f15-4759-973a-e57a17a843c0',
#   'userName': 'Janine Wesley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKyelLnqlfxZL_qNyEEuEyTIxJEFpS0JG1HgTjMhJcO=mo',
#   'content': 'Jam.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2023-04-21 16:43:15'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.998353123664856}]},
#  {'reviewId': '21e85de7-91de-4bc4-a86e-6028c0be60ab',
#   'userName': 'wiremu layne',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL47IGQOaRd9zA1oiABtcoPeM7xm_DqaBBEcpUogFVDpA=mo',
#   'content': 'This A Awesome Brotha',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2022-12-30 05:07:25'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9976692795753479}]},
#  {'reviewId': '014143c9-87a8-459c-8427-d4281c9dcc1b',
#   'userName': 'Jdeann Dobyns',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIdHWgVTsNazVW4nQDVqHiHLeKtQ6QS2SvW97H6vm8q=mo',
#   'content': 'yay',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-11-13 06:06:09'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.99868243932724}]},
#  {'reviewId': '0b09d40a-afec-4446-9111-7a1f47628f69',
#   'userName': 'Mac Mcdaniels',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJ6mHDL1ls-nmCainJfxpeI8oHjHohsrkaTrMk4hTzm=mo',
#   'content': 'Good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-10-12 15:37:53'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.998848557472229}]},
#  {'reviewId': 'c3270a05-98e8-46af-a93c-4441497a420b',
#   'userName': 'Karen Neal',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI6d80kleQ4L7l8Sh9oqfIT7cAENRs_aKr6oyphb3Cl=mo',
#   'content': 'AWESOME.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-07-30 06:18:32'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.998386025428772}]},
#  {'reviewId': '2917315f-8c34-4262-b9c1-5b3c2d840483',
#   'userName': 'Amanda',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU4qH0Tc76rG6kB4BJ48IZ9wrDUmEkapeJo5wXdiuWLGvk',
#   'content': 'Fun game...',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-07-15 21:06:06'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988138675689697}]},
#  {'reviewId': 'aba307a4-6554-4f36-961f-db0812d63c1b',
#   'userName': 'Theresa Lafferty',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWgS6GP5YnL4-RdNGEIPG-hnvgvx1IonUpb3UBpRijHjoY7',
#   'content': 'I love this game!! I like it when Popeye helps you with matching the tiles.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-06-23 22:10:09'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988968372344971}]},
#  {'reviewId': 'd00a76de-ed3c-4ef6-a2d8-6415ddb06024',
#   'userName': 'LaRayne Beaverhousen',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXo3suq7seYOhS96CUoS3jRr7-eKYI-HNYGEyxXKgR6iMs',
#   'content': 'Needs more perks to be able to keep playing , as not everyone is able to purchase coins to keep going in the game .',
#   'score': 2,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-06-10 08:26:23'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'NEGATIVE', 'score': 0.995418906211853}]},
#  {'reviewId': '40f20a60-79e3-415b-8c8e-47875a478298',
#   'userName': 'Judy Johnson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJyULNFjsTq_vnZnOTPp9ntHKlY9Dx0LgialhQkt5S1=mo',
#   'content': 'Enjoying it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-06-03 18:53:48'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988973140716553}]},
#  {'reviewId': '0fd45fe2-1ffd-44b3-9116-7c08a7a1fbc1',
#   'userName': 'Lori Lewis',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJqr6IbHBYmusQtcBs39sPHUp73wpwy5LJQRBNKh4Km=mo',
#   'content': 'Love this game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-06-01 16:07:41'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988817572593689}]},
#  {'reviewId': '0c9f8ffe-d4a1-475c-9236-e77bfdf8251d',
#   'userName': 'Sylvia Adams',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVL5yL1LjaMiiPnEc_AKxYFqFCBKVDzX5HkQcxkphioN-lB',
#   'content': "Fun game. I used to watch Popeye cartoons way long ago. It's a fun game.",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-25 05:47:52'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987733960151672}]},
#  {'reviewId': 'fb9cb284-1ee7-42c8-bc6e-17a84924dd87',
#   'userName': 'Glendaf Giles',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLTCuTv1xxZPir0QxXBCeNZGDkEZKOJOHzNpjb93nRX=mo',
#   'content': 'A Great Game..Relaxing Fun..Love It.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-21 16:32:54'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989253878593445}]},
#  {'reviewId': '72d65840-0059-4499-9bc1-fb1ffbf63ba0',
#   'userName': 'Irene Sim',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjV2AGwA94CNIeSAjo8HotWHxcwjtldqVbGaK7EzsdLDQf1X',
#   'content': 'I love Mahjong',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-21 14:19:04'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987731575965881}]},
#  {'reviewId': 'becc4a52-a7d2-4d79-ba0e-2d613fcb0f9f',
#   'userName': 'Jose Concepcion',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL_SKv7Xq7Nb8sP7RE02nNIttkOSOxjHMfRNLuAO91a=mo',
#   'content': 'Love the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-20 16:36:39'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988778233528137}]},
#  {'reviewId': '20e35c4e-9154-49e7-8c01-66a0077e3a98',
#   'userName': 'Sulis Clarin',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWW11_IUlSkmhpZ5h1BZFlNgKxZyYy0iTIcL5NrIIS6Sv4',
#   'content': 'Awesome',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-19 05:01:59'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986000657081604}]},
#  {'reviewId': '057294a4-77c0-4e33-a5c2-ae9b13943fc7',
#   'userName': 'Eldorina Gaskin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKcnUnRxVVWtXfSFfMG2m-XEY2ZIkgVf56sV5rDY5-D=mo',
#   'content': 'Cool',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-19 02:28:09'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9969148635864258}]},
#  {'reviewId': 'e435f93f-73de-4bd5-8362-75eb3a29b745',
#   'userName': 'rosalie peterson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIudHPONr44boOQLyJm4FjpZ4y4yI9xNvFvlfkzZlp-=mo',
#   'content': 'love the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-17 14:42:36'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988797307014465}]},
#  {'reviewId': 'ea11fdeb-9ab3-494e-94b3-6be856f92313',
#   'userName': 'Zachary Buszta',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU_5bVTK-IDTKvpNbgnB30Wyz7In26WO0BscM2Yc_Rr',
#   'content': 'This game is fun to play',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-12 02:29:57'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988828301429749}]},
#  {'reviewId': '1af5e1c4-272e-43eb-b0a8-de098a11731a',
#   'userName': 'Joe Ossinger',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJxadj4q2GLK5HQAjKZr7juRt88TREvx6Pr1RoP3Lpt=mo',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-09 01:42:05'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988111257553101}]},
#  {'reviewId': '1f06fb76-e5a8-4502-bd74-a7d095de2ed2',
#   'userName': 'Cynthia Terrell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIMNy3ECzecOR7tt3qBeSmUcwwlYH9Td6qj3e2wqIut=mo',
#   'content': 'I think this game is great',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-06 17:58:42'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988355040550232}]},
#  {'reviewId': '0cdf9d51-08fe-4cad-bcdb-29925593b1f1',
#   'userName': 'Patrick Collins',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocITacuLK4ZqkEXwzFHlo2oXhwGELG9_H-Gi35n5l28j=mo',
#   'content': 'Ok, different and FUN!!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-05-06 05:57:40'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986081719398499}]},
#  {'reviewId': '5f526c0a-8f63-4ea7-96ec-1065db19c75c',
#   'userName': 'Janet Dear',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIeyyJDz3sAWuSLnBUJWNCYpXzuyScstAcu_fdVGSW1=mo',
#   'content': 'Omg another addictive game love it 👍💖',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-28 09:47:23'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988790154457092}]},
#  {'reviewId': 'af5907de-ca71-4dd9-97ee-732c6ccc19b7',
#   'userName': 'Veronica Paton',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXL3CwM5ApfL6h8W53U-XxaofX9vSymuGuDiAWf6cJublsm',
#   'content': 'Fun game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-21 12:15:38'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988071918487549}]},
#  {'reviewId': '2b49c7fb-2385-4ad5-aedc-86c33298e363',
#   'userName': 'Gayle Jordan',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKmdkF1Vh2p5cztxzcjjRAFCzYve7ihCW29SONQ3pl_=mo',
#   'content': 'Fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-15 21:20:38'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987583160400391}]},
#  {'reviewId': '9e518086-b1fa-41eb-8483-f1b52762e08b',
#   'userName': 'Darla Bleeke',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJxLcl8-y7qBx0yFKIFx7pvyiXOhqrAuhJSMEMtesqh=mo',
#   'content': 'Fun so far...',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-15 03:46:45'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986022114753723}]},
#  {'reviewId': '1a602680-6e30-47c2-9381-4272c9216c79',
#   'userName': 'ROSA GONZALES',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJIWowS2lHPka62ZiLclDMap5ntLNikCoOfE45cqcN=mo',
#   'content': 'GREAT GAME!!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-15 00:24:12'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987063407897949}]},
#  {'reviewId': '1ffad054-5dff-4132-9b94-c2872b40b048',
#   'userName': 'Stacy Kelly',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXWjEisCBINziOHuOXS-hHE4fuPl2bDkkbuM9oSpVyAABY',
#   'content': 'This game is alot of fun and excitment in it , u will love it',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-14 08:14:59'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988994598388672}]},
#  {'reviewId': '68a40c96-2fb9-4540-861b-594e9836880a',
#   'userName': 'mary mahoney',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK85W7XMt1BqUQUHehPVrrotithDly9AdZyX_SyFPBU=mo',
#   'content': "Hi I like mahjong it's a good game that's why I rated it 5 stars for love maryanna Mahoney",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-04-12 04:19:32'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988428354263306}]},
#  {'reviewId': 'd85696e8-9fd8-47eb-b8c1-67a5dd859e3b',
#   'userName': 'Carolyn James',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLEljdM6cut9DyW8iqVV_TuvaAMyHksBeMLn_CaQZ_R=mo',
#   'content': 'I like this game.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-11 20:16:48'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988818764686584}]},
#  {'reviewId': 'be88bdee-cde5-4bc9-b353-e4f9f2e082f4',
#   'userName': 'Mandy Pugh',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIL_ljGUm1U0RY5guxv0N5ZUys4-Zxn5NX_9fWeoUkr=mo',
#   'content': "I just started..but i.love MAHJONG games...so I don't see any problems so far.....",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.13',
#   'at': Timestamp('2022-04-06 07:04:57'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.13',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986907839775085}]},
#  {'reviewId': 'd04440c3-df1d-4119-a436-6eaf863c606f',
#   'userName': 'Regina Phillips',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKUHuKxAYTcSpxCgb4yFS8Vs2vJE4HHdMea5Fc6mSpo=mo',
#   'content': 'Lots of fun 😊',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-03-12 08:01:49'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988117218017578}]},
#  {'reviewId': '7ecbd229-e65f-423b-afe5-cdd04d48a05f',
#   'userName': 'Janice Turner (JanWolf)',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWYm87VfWIl2VxYP_Fv6padANhbS-EqUIqMztywahFo0WE',
#   'content': 'This is a very very fun game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-03-06 18:06:33'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988318085670471}]},
#  {'reviewId': 'fc3416e9-296f-462a-844b-26e04af0b695',
#   'userName': 'Souzane Mahmassani',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJNmvrMeskrAy6UIukHQjQGN09-KncKg2fXoDdVZXA5=mo',
#   'content': 'Super',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-03-02 16:51:46'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9985753297805786}]},
#  {'reviewId': '73bde7d3-00c1-44d2-8d25-a89ea52a20c4',
#   'userName': 'Crystal Frye',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVAsT5l_v8pKs5NjPml1pp-BIWidThDG6TNd8fKrQWyFXWu',
#   'content': 'Very relaxing and Popyee helps me along the way with explaining how the game works without interfering with the play of the game itself. It is not to easy but on the other hand it is not to hard. I feel that is why I like this game and app.',
#   'score': 5,
#   'thumbsUpCount': 16,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-02-14 01:24:53'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989380240440369}]},
#  {'reviewId': 'f7c27166-aee9-4d23-96bc-b9eba5a9af25',
#   'userName': 'Loretta Adkins',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXSg65kevM3dFriIc0qaX0GZsLDAkYp97Yu9Xa5LCcmGg',
#   'content': 'i love this game it is fun to play.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-02-08 22:02:55'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989129304885864}]},
#  {'reviewId': '24660f30-f69e-4ae2-9df7-f13d575c2dcb',
#   'userName': 'Conner Mcdaniel',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKPLaZ8cja3tYI7MuUMejJqBucG49GjH6c3w3dYPsva=mo',
#   'content': 'Fun game gives my brain a workout',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-02-01 05:48:53'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988420605659485}]},
#  {'reviewId': 'a69e0dcd-7bba-4446-b44a-128db9e7d313',
#   'userName': 'Elizabeth Hughes',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjUi0f3_oO9AeBnNDWO25_cK_wZTDrBIxDQcbRpEi_pS6mk',
#   'content': 'Fun & challenging',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-01-25 15:04:37'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988376498222351}]},
#  {'reviewId': 'e7ea9818-d637-4c06-be5c-681e7b761bb5',
#   'userName': 'Lynett Percell',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKq0oD6XqVRVVWIclZU59CbQP_lLcAAeAboEdE-7QFz=mo',
#   'content': 'Easy, relaxing and fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-01-15 23:09:31'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989104270935059}]},
#  {'reviewId': 'c16b282d-fa74-4dd0-a02b-66eb862a922c',
#   'userName': 'Daisymae Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIPjPVtj46jONIAwxa9WDcu6X5JvcuRZTiNa2S9yID8=mo',
#   'content': "Great game it's challenging",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-01-10 14:18:43'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988952875137329}]},
#  {'reviewId': '6a072536-cc37-45c3-881f-702396964662',
#   'userName': 'Sarah Cockburn',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIwNF_DijicaLuD-q1UEmpHtASgLW1irhs9QQKtuvlR=mo',
#   'content': 'Good fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-01-04 04:00:06'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987861514091492}]},
#  {'reviewId': '0565fafc-2a3a-495a-a673-a9126e8d1821',
#   'userName': 'Donna LaBelle',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIjBYGcLgEtbx7cfFDJ3Hu7gFNfiWp_Yjqnd2vSs72F=mo',
#   'content': 'Not bad . A little childish.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2022-01-02 00:54:19'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9948478937149048}]},
#  {'reviewId': '1e4d6bdd-bf9c-459c-a7d1-d3eb0076ba7c',
#   'userName': 'Colin Bates',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJWqL8mOQ5ohzXzSQq7_1Py-ncu7T4JQrebFysR0pN7=mo',
#   'content': 'Great to play',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-30 10:11:41'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987227320671082}]},
#  {'reviewId': '7690f09a-2c4d-4471-b9e3-6c8ba7f98ec8',
#   'userName': 'Julie Carter',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXwwDS8sV4FgqnGSkVaunR2YOqkKgW5qmMbU85Bsru0Ew',
#   'content': 'Ii like it. Its not to easy and sometimes its pretty hard but not impossible',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-30 09:43:52'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988203644752502}]},
#  {'reviewId': 'ce64e9c2-e347-458a-809c-cba7239650c3',
#   'userName': 'Audrey Brown',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI-LcnKillY_tioEZbgx7lFEHFHne1cygpANmkxYYgW=mo',
#   'content': 'Awesome Very. GRAPICS',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-29 15:52:15'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9981763362884521}]},
#  {'reviewId': '29cca975-5dd6-4542-a25d-b7e71333357b',
#   'userName': 'steve brister',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocI_wIXhWk7KJojEGza8IcNATBk-GxdKMBqhxO1Mc5Z1=mo',
#   'content': "It's more for the kids.",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-28 08:00:53'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9980912804603577}]},
#  {'reviewId': '8cec8a53-d0b2-422b-a5c4-2534520f383b',
#   'userName': 'Victoria Foster',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL6G-rUbmtU5aHyQfsQc3xlCUrxRM_Hp1QVQ-8puq9i=mo',
#   'content': 'Silly and fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-27 13:56:16'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986339211463928}]},
#  {'reviewId': 'e5e97d40-d212-45c6-ba3d-788a0e5c8f83',
#   'userName': 'Lisa Malone',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLlm11l6WXrcouoWKACnmD5mV861Z6_QaZEqA3yZyXP=mo',
#   'content': 'Enjoy getting to the next level',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-27 04:33:36'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.998877227306366}]},
#  {'reviewId': 'f6f242c9-aa1a-41aa-ac14-f16d54926b45',
#   'userName': 'Margo Kelley',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKFlC7cPSN97lz21uh0M2BWZq6D6B9Mxu9rVOU-ZAu4zA=mo',
#   'content': 'Helps me too relax',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-26 22:20:36'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988541603088379}]},
#  {'reviewId': '37c1b1d1-79a5-4b16-b69f-ae8bd650acce',
#   'userName': 'Alana Brown',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIPcO3uVFqUrNTiZdBZEOhZ9ZP7s5uRWgI7fJLDK-gz=mo',
#   'content': 'game would not let me play',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2021-12-16 00:12:55'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'NEGATIVE', 'score': 0.9994875192642212}]},
#  {'reviewId': 'aec7790a-4830-4c5c-b240-a4e92792498c',
#   'userName': 'Marianne Hinrichs',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKCImmHf0xKEaFQrGmiiWVirtuH6hEYj5UQrhPomzIE=mo',
#   'content': 'this is fun an you have to think to make yourovr',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-14 10:20:08'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987993240356445}]},
#  {'reviewId': '3a486da7-cff0-4608-b3e3-c7ae229764cc',
#   'userName': 'Melodee Hacker',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXRXRGOQ59446fkK88amdUSonwBZ2P33zxwPmwOdA8fEh4',
#   'content': 'Fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-13 19:46:04'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987583160400391}]},
#  {'reviewId': '958f29a9-3730-4da2-bcef-3073d33e25bf',
#   'userName': 'Tammy Simpson',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIe78JxS-iHX_-_qkZVFWmtd3-LcVo87y-d-nQ3EcCh=mo',
#   'content': 'Good game',
#   'score': 1,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2021-12-09 23:20:38'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.998848557472229}]},
#  {'reviewId': '740b8f4a-a966-49d3-8013-caee19a39a9c',
#   'userName': 'Ronald Bianco',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKZ3bRZuvoY1XNO7jpYNzRGURYy3mgl1_y_XJCfnF6k=mo',
#   'content': "A fun game to play. I wish that I could slide to connect, but i can't. BE SAFE, GOD BLESS ...",
#   'score': 4,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-08 19:04:49'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9983333945274353}]},
#  {'reviewId': 'd08b3c8f-14e8-461f-ab2b-4347696f86e8',
#   'userName': 'DeLinda Wagner',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJuTFIjfRJHtwS14PrBvcNOWezhb_6zZ8MhcQTXdcVP=mo',
#   'content': 'Fun and can get challenging at times',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-04 05:24:51'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987254738807678}]},
#  {'reviewId': '285b4e2c-fc96-4610-8255-8e2119c1a441',
#   'userName': 'Kristine Barfknecht',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjX9Lvnn6wJ_dkJisH5M8jy9ZRV2ypkgUJYSJXf_2Z9sqY0',
#   'content': 'Alot of fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-01 22:06:13'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986936450004578}]},
#  {'reviewId': 'fa427c76-57cc-4e46-b952-ca55021d1441',
#   'userName': 'Britt Jones',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLJgJDWwxXk-pxJs7f1hIsAShr9mt6TBqbNla0YLa60=mo',
#   'content': 'Fun',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-12-01 05:37:30'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987583160400391}]},
#  {'reviewId': 'b90ae393-cd47-4a03-9df8-0fff6c90be4d',
#   'userName': 'Angela Comstock',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVBw4qg2iuvQuqCkCrKfNnyDAHaOsuzYbVRv1gNylD4Iq4I',
#   'content': 'Love this game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-30 13:43:02'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988817572593689}]},
#  {'reviewId': '6531c4d5-a297-42a7-b743-3c5f2331ac74',
#   'userName': 'Angela Rotundo',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKTD4Mmp8h3eNP88JwlKJDkBwvnfTKAfJfE4xa8j0-s=mo',
#   'content': 'Like the fact no vendors to watch during levels',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-29 21:55:03'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'NEGATIVE', 'score': 0.9994431138038635}]},
#  {'reviewId': 'd9f3a434-7059-471f-a2cb-49f5e3c23aca',
#   'userName': 'Lolita Tesoro',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKXzbi-RAF4LrGhBInuswNs5nlW6Cjq_v1-Fv12ogA1=mo',
#   'content': 'I like how the pieces start',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-28 08:00:51'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987176656723022}]},
#  {'reviewId': '2acdf2bf-ab63-4035-a4d9-d448d55e2195',
#   'userName': 'Nathan Esparza',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLRxe5vzqF-wp-w0ABPRbo1HfFKSdDLX56u_DUwuFUS=mo',
#   'content': 'Not a bad game at all',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-26 20:38:08'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9980576634407043}]},
#  {'reviewId': '02fb1cbe-29c4-43f5-bf52-777ff578d648',
#   'userName': 'Alan Thomas',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjU3IZiFyakFy4q4q3A479z9-Dn8Lp-MonM2jLkpo4v-JQ',
#   'content': 'Good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-26 15:11:41'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.998848557472229}]},
#  {'reviewId': 'b719f774-95ed-47f7-b431-5ff39bb481db',
#   'userName': 'Troy Raber',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJGzHCKsXRLKYRyrD37NDs25B0j7YIZXf01LmMAq41f=mo',
#   'content': 'Boring',
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-24 23:59:56'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'NEGATIVE', 'score': 0.999426007270813}]},
#  {'reviewId': 'c90445d1-5214-479d-8bdc-42efaf31047d',
#   'userName': 'Carol Ryckert',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKdC-LcRb0F7pqN9SkDRq-ngwKC-eXScmnUS2jjU5X4=mo',
#   'content': 'just keep you occupied for a while.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-23 09:53:03'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9915550351142883}]},
#  {'reviewId': 'df30b4fa-3018-4d1e-b4fb-88e6f00951ed',
#   'userName': 'Msrgaret Flores',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocKWTumrhkAtZqGSAwmlaZcvKh313S9SHzzSw4HYUzod=mo',
#   'content': 'Fun fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-21 13:32:55'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988138675689697}]},
#  {'reviewId': '65d1b1ac-9f95-4fc3-af2c-6853c70b099d',
#   'userName': 'kim graham',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLuOTL6ACJyA1o8GgUH-FejDKGaHcU4W-yAxZrhV5ql=mo',
#   'content': 'Good game so far, loads fast no glitches',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-20 17:58:35'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989118576049805}]},
#  {'reviewId': '1381b794-6a25-49f2-8bbe-b20ce391b480',
#   'userName': 'kehli armstrong',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIsWx0kbmhT0C1ZyXXv-5PGgAbryP2S8U0FVDezLXys=mo',
#   'content': 'Fun and entertaining',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-17 23:26:56'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988422989845276}]},
#  {'reviewId': '675789e1-5ffc-4cd6-b772-7d137f8e4fad',
#   'userName': 'Catherine Martin',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocJsySZU_u-6zN5DYJ2GhbYiGLCrdrEen4IpXpSMM5ar=mo',
#   'content': 'A fun game to play!!!!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-17 21:12:09'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.998881995677948}]},
#  {'reviewId': '6b66c573-fdf8-4842-a57c-c98022e139ae',
#   'userName': 'Lady Van Niekerk',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocK2n6Gn-OHTQQm3d1DmXGxyRvqMFJTCzeHk6TqMnBqr=mo',
#   'content': "Can't get past level 193 I just luv this game pse help me please I would live to go to 194 to carry on pse the so much lady from south africa",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-16 10:30:24'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9984797835350037}]},
#  {'reviewId': '25ad56f7-2033-4f21-9d93-7c2ac985fb54',
#   'userName': 'April Stamant',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVy_nf_xxTf6uaS5zhvOHGZpjAjydInF6D205B4nfvtZB8',
#   'content': 'So far so good',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-13 21:14:01'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9981192946434021}]},
#  {'reviewId': '3d5a74dd-59e7-4db9-bff2-d987364b4319',
#   'userName': 'Dorothy Linen',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocIehQpyEB3vMrb21vKCTlaX98_If3ULY3LXYbngLDHU=mo',
#   'content': 'The game is relaxing fun and easy. I really like the game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-13 09:18:20'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989294409751892}]},
#  {'reviewId': '11f56f57-e820-48ca-9303-ccde49c3bbf4',
#   'userName': 'Maryanne Tinder Osborne',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWQ5iBTVXEVcjdgmrImkUt_IybqvMdPOJHrdTRyltzIuQc',
#   'content': "It's OK and uses your brain for sure",
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-12 23:24:14'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9952669143676758}]},
#  {'reviewId': '58033e01-b004-4ced-8003-ef88a08a2112',
#   'userName': 'rebecca chick',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocL_JVQrMDiWTHZ28-nLFLX-YV6LlPCAaPuudtWbfWmssA=mo',
#   'content': 'Very good game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2021-11-10 20:49:37'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9987832903862}]},
#  {'reviewId': '0c2b419d-2295-42d1-b803-eddca42ba869',
#   'userName': 'Aurea Cubero',
#   'userImage': 'https://play-lh.googleusercontent.com/a/ACg8ocLueqmBOz2msxmlMP2bb72_mzNb1h6QnK5X51Tab4_W=mo',
#   'content': 'Great game',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-10 07:24:34'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.998761773109436}]},
#  {'reviewId': '2f33eeac-fb22-47e9-8ce8-e67f88fa8e8b',
#   'userName': 'Shana Rahman',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjWgypEhfrK8AoRtXi0Ez30fL9u02K9rINLwijZT13yTg04L',
#   'content': 'Love this game... passes time',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-08 15:08:01'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989211559295654}]},
#  {'reviewId': 'cdb40e91-d90f-44bd-b42c-a3d4169d26c9',
#   'userName': 'Anita Ann Ogden',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjVmT_0sUBT2mlwdAcJ4r40pMa29hmCO1mmHn30q24XTfpY',
#   'content': 'Fun and relaxing',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '2.0.7',
#   'at': Timestamp('2021-11-06 21:03:32'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '2.0.7',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988670349121094}]},
#  {'reviewId': '552a0e21-ce98-4a91-855c-630e650844c7',
#   'userName': 'Darlene Sensky',
#   'userImage': 'https://play-lh.googleusercontent.com/a-/ALV-UjXtk5RagGUfdt5YEGbtieF7tN6afjvBV7F5yD94FjcZkL4',
#   'content': 'Great Mahjong game! I love Popeye. He was my favorite when I was growing up!',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2021-11-06 16:32:54'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9987767338752747}]},
# ...
#   'appVersion': '1.1',
#   'result': [{'label': 'POSITIVE', 'score': 0.9984955787658691}]},
#  {'reviewId': 'd40cb1ef-62fd-4ff8-88d2-056f50e61acf',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Nice game.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': Timestamp('2016-10-02 00:11:58'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987847208976746}]},
#  {'reviewId': 'df6df421-1680-48b4-a8ba-5fa935555819',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'It stops at level 86.',
#   'score': 3,
#   'thumbsUpCount': 5,
#   'reviewCreatedVersion': '1.1',
#   'at': Timestamp('2016-10-01 04:52:58'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1',
#   'result': [{'label': 'NEGATIVE', 'score': 0.9985124468803406}]},
#  {'reviewId': '1f0930ef-e6e9-4108-8f2d-d45999115024',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'I like all solitare ,another one play.FUN!',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.1',
#   'at': Timestamp('2016-09-25 18:24:40'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987784028053284}]},
#  {'reviewId': '0aca9459-5e86-440e-80c3-db66014618e7',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'I love the fun sounds and colors. The game is not annoying and easy to play. : ) ...I like it!!!!!',
#   'score': 5,
#   'thumbsUpCount': 11,
#   'reviewCreatedVersion': '1.1',
#   'at': Timestamp('2016-09-25 03:06:10'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.1',
#   'result': [{'label': 'POSITIVE', 'score': 0.9989237189292908}]},
#  {'reviewId': '7c0d2a7f-e840-4fea-9328-348aa4467fbc',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'loved it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-23 06:40:36'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988114833831787}]},
#  {'reviewId': 'bc378749-4835-4345-bc5d-11013c2eb27c',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'One of my favorites',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-19 00:18:20'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.998840868473053}]},
#  {'reviewId': 'ca4ceb49-2572-4b63-8dbb-a29a0f982900',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Fun times.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-17 22:04:32'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987496137619019}]},
#  {'reviewId': 'bec911e5-7f52-4fbb-80b1-aa5384f15ca5',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Fun.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-17 18:51:22'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987873435020447}]},
#  {'reviewId': 'bd8822ec-a4ff-4487-a849-d1e7d10f1a70',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Love it',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-16 22:31:01'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988111257553101}]},
#  {'reviewId': 'b881e7b4-cbc0-400a-9447-31f1bb864520',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Ok',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-15 09:49:58'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'NEGATIVE', 'score': 0.9943146109580994}]},
#  {'reviewId': '3912bdc9-db00-4888-929b-860fc1e9b6f2',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "Great game I'm finding it very addictive",
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-06 20:24:44'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.998842716217041}]},
#  {'reviewId': '054d5e04-f496-4f93-8282-58dfb33b68b2',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Nice game keeps yah busy.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-06 03:51:18'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988391995429993}]},
#  {'reviewId': '59ce21ef-168e-4314-994a-cb44ce827814',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "But I'm sure it'll get more appealing as I play the game further  😊",
#   'score': 3,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-09-06 02:01:12'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9981679916381836}]},
#  {'reviewId': '573afe34-e514-42d7-adee-09a7bc5f7b13',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Good game like the underwater scenes and tiles',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-31 13:20:32'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.998845100402832}]},
#  {'reviewId': 'f1ceced7-6371-48b8-a2ed-4ca01695994d',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "It's got nice music and cute tiles",
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-29 20:26:49'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.998868465423584}]},
#  {'reviewId': 'e3784b8b-aa63-4f05-818f-26854d304201',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "My Little ones like it. Good for short attention spans of kids, before they get bored game's over.",
#   'score': 4,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-27 02:22:54'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9986995458602905}]},
#  {'reviewId': '4a368a8f-345e-4766-ab78-0231eba93672',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Love it and it was a blast',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-25 18:30:04'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988943934440613}]},
#  {'reviewId': 'fb5f20b3-b722-4208-9e0c-ad097d1db03a',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Thks',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-18 07:06:30'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9366508722305298}]},
#  {'reviewId': 'e79b3cf1-c94e-4ebf-aaaf-fb1302988a8b',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': "It's fun",
#   'score': 3,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-18 01:37:55'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987567663192749}]},
#  {'reviewId': '29853424-14e9-4a21-b9b0-2bfdca5a716b',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Lot of fun',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-16 01:27:20'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987866282463074}]},
#  {'reviewId': 'e691b4e2-65d3-49b9-82cb-2df17605d425',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Trying another game so addictive !!',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-14 21:56:17'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9982998967170715}]},
#  {'reviewId': '4b8e4f6e-9b09-44b8-a7ae-6b3de2ae0fd9',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Moving all the tiles until the board is completed with all tiles matching',
#   'score': 5,
#   'thumbsUpCount': 3,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-13 23:32:45'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9984264373779297}]},
#  {'reviewId': 'd05be434-84a9-40e4-b148-6a81a9b34f45',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Great game.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-11 00:19:08'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9987449645996094}]},
#  {'reviewId': '7c967967-49ed-4284-ac7a-6a98aae64f6c',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Excellent.',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2016-08-10 13:59:12'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9985287189483643}]},
#  {'reviewId': 'bc7c1dfc-92f2-4797-90a7-9134c119e83d',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Its good game thanks.',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-10 07:44:48'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.998838484287262}]},
#  {'reviewId': 'e9770837-a3d0-406d-9173-26ac8fd0fba1',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Gotgold',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-09 13:48:35'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9956445693969727}]},
#  {'reviewId': '2611b8d2-8dd7-4cf4-b816-e36b0da11892',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Its a good game to play',
#   'score': 5,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-06 01:43:53'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988006353378296}]},
#  {'reviewId': '4275ee7f-98f0-4548-bb21-10c8c5d7eb62',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Relaxing',
#   'score': 4,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-03 23:27:52'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9988724589347839}]},
#  {'reviewId': '194679ca-5ef2-480e-b64b-84fb2b99d6ac',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Like the tiles',
#   'score': 5,
#   'thumbsUpCount': 0,
#   'reviewCreatedVersion': None,
#   'at': Timestamp('2016-08-03 07:34:42'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': None,
#   'result': [{'label': 'POSITIVE', 'score': 0.9984444975852966}]},
#  {'reviewId': '110b9f80-3135-4e90-9a1c-b10102d19625',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Loved',
#   'score': 5,
#   'thumbsUpCount': 2,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-08-01 07:44:52'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9984955787658691}]},
#  {'reviewId': '4df0c0ad-ac36-4aaf-8c06-e84806abd46f',
#   'userName': 'A Google user',
#   'userImage': 'https://play-lh.googleusercontent.com/EGemoI2NTXmTsBVtJqk8jxF9rh8ApRWfsIMQSt2uE4OcpQqbFu7f7NbTK05lx80nuSijCz7sc3a277R67g',
#   'content': 'Good job try to improve your self',
#   'score': 4,
#   'thumbsUpCount': 1,
#   'reviewCreatedVersion': '1.0',
#   'at': Timestamp('2016-07-31 11:29:20'),
#   'replyContent': None,
#   'repliedAt': None,
#   'appVersion': '1.0',
#   'result': [{'label': 'POSITIVE', 'score': 0.9982858300209045}]}]
